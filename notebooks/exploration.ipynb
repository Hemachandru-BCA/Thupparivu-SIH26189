# %% [markdown]
# # Exploration
# Explore the synthetic dataset and pipeline artifacts.

# %%
import sys, json
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))

print('Project root:', ROOT)
