# %% [markdown]
# # Graph Testing
# Load the built graph and prototype analytics/ghost queries.

# %%
import sys, json
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))

print('Project root:', ROOT)
